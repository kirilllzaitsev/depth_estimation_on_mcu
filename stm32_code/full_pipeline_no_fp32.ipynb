# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
from utils import set_seed
from plot_utils import plot_eval_results

set_seed()

# %%
from mnist_utils import plot_samples
from config import cfg
from vanilla_model import fit as fit_vanilla
from metrics import calc_metrics
from converters import Converter
from config import cfg
from eval import run_tflite_model
from c_utils import write_model_h
from utils import save_test_data
import plot_utils as pu
from model import get_model
from model import save_pruned_model
from utils import get_gzipped_model_size

# %%
from nyuv2_torch_ds_adapter import get_tf_nyuv2_ds
import argparse
args = argparse.Namespace()
args.truncate_testset = False
# args.target_size = (64, 64)
args.crop_size = (640, 480)
# args.target_size = (64, 64)
args.target_size = cfg.img_size
args.out_fold_ratio = 1
args.is_maxim = False
cfg.do_overfit=False
args.batch_size=cfg.batch_size*4

ds_train, ds_val, ds_test = get_tf_nyuv2_ds(cfg.base_kitti_dataset_dir, args)
# train_size=cfg.take_first_n
# ds_train = ds_train.take(train_size)
# val_size=cfg.take_first_n
# ds_val = ds_val.take(val_size)
# test_size=cfg.take_first_n
# ds_test = ds_test.take(test_size)

x_val= next(iter(ds_val))
x_train= next(iter(ds_train))
# Out:
# Dataset: NYU Depth V2
# # of train images: 50688
# Dataset: NYU Depth V2
# # of test images: 654
# Train size:  40551
# Val size:  10137
# Test size:  654

# %%
x_train[0].numpy().max(), x_train[0].numpy().min(), x_train[1].numpy().max(), x_train[1].numpy().min(),
# Out:
# (1.0, 0.0, 0.254, 0.018)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(x_train[0][0].numpy())
axs[1].imshow(x_train[1][0].numpy())
axs[0].set_title('Image')
axs[1].set_title('Depth')
# Out:
# Text(0.5, 1.0, 'Depth')

# %%
import os
converter = Converter(cfg)

# cfg.save_model_dir = "/tmp/models"
# cfg.save_cfiles_dir = "/tmp/cfiles"
# cfg.save_test_data_dir = "/tmp/test_data"
# cfg.do_overfit = True

os.makedirs(cfg.save_model_dir, exist_ok=True)
os.makedirs(cfg.save_cfiles_dir, exist_ok=True)
os.makedirs(cfg.save_test_data_dir, exist_ok=True)

# %%
model_names = [
    "depth_model_quant8_dynR",
    "depth_full_quant",
    "depth_qat_int8",
    "pruned_model",
    "pruned_model_unstructured",
    "pruned_model_unstructured_dynamic",
    "pruned_qat_model",
    "depth_model_fp32",
]
cfiles = {
    "depth_model_quant8_dynR": "depth_model_quant8_dynR",
    "depth_full_quant": "q8depth",
    "depth_qat_int8": "qat8depth",
    "pruned_model": "pruned",
    "pruned_model_unstructured": "pruned_unstructured",
    "pruned_model_unstructured_dynamic": "pruned_unstructured_dynamic",
    "pruned_qat_model": "pruned_unstructured_qat_model",
    "depth_model_fp32": "depth_model_fp32",
}
save_test_data(cfg.save_test_data_dir, x_train[0], x_train[1])
# Out:
# Test image data location:  /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/test_data/x_test_depth.npy
# Test labels location:  /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/test_data/y_test_depth.npy

# %%
import pickle
from eval import eval_model
from loss import calculate_loss
from model import get_model
import tensorflow_model_optimization as tfmot


def fit_eval(model, model_name, do_save_model=True, epochs=cfg.epochs, do_savefig=True):
    keras.backend.clear_session()
    # loss = tf.keras.losses.MeanSquaredError()
    metrics = tf.keras.metrics.Mean(name="loss")

    # Define a custom metric
    def custom_metric(y_true, y_pred, sample_weight=None):
        metric_value = calculate_loss(y_true, y_pred)
        metrics.update_state(metric_value, sample_weight=sample_weight)
        return metric_value

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0005)

    model.compile(optimizer=optimizer, loss="mae", metrics=[custom_metric])

    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="loss", factor=0.2, min_lr=1e-7, patience=5, min_delta=1e-2, verbose=1
    )
    callbacks = [reduce_lr]
    if "pruned" in model_name:
        callbacks.append(tfmot.sparsity.keras.UpdatePruningStep())
    if not cfg.do_overfit:
        tbCallBack = tf.keras.callbacks.TensorBoard(
            log_dir=f"{cfg.logdir}/tb_logs",
            histogram_freq=0,
            write_graph=False,
            write_images=False,
        )
        es = tf.keras.callbacks.EarlyStopping(
            patience=cfg.es_patience, restore_best_weights=True,
            min_delta=5e-3, 
            monitor="custom_metric",
        )
        model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
            filepath=cfg.logdir + f"/{model_name}",
            save_weights_only=True,
            monitor="custom_metric",
            mode="min",
            save_best_only=True,
        )
        callbacks.append(es)
        callbacks.append(model_checkpoint_callback)
        callbacks.append(tbCallBack)
    history = model.fit(
        x=ds_train,
        epochs=epochs,
        validation_data=ds_val,
        callbacks=callbacks,
        verbose=1,
    )
    # pickle history
    with open(f"{cfg.save_model_dir}/{model_name}_history.pkl", "wb") as f:
        pickle.dump(history.history, f)

    # plot history
    pu.plot_history(history, f"{cfg.save_model_dir}/{model_name}_history.png")
    if not do_savefig:
        plt.show()
    tflite_path=None
    model_tflite=None
    if do_save_model:
        model.save(f"{cfg.save_model_dir}/{model_name}.h5")
        model_tflite, tflite_path = converter.keras_to_tflite(model, model_name, do_return_path=True)
    # tflite_path='/tmp/models/depth_model_fp32.tflite'
    metrics = eval_model(
        model=model,
        test_ds=ds_val,
        tflite_path=tflite_path,
        model_name=model_name,
        metrics_file_path=f"{cfg.save_model_dir}/metrics.json",
    )
    return model_tflite, metrics, history

# %%
# load history
# with open(f"{cfg.save_model_dir}/{model_names[7]}_history.pkl", "rb") as f:
#     history2 = pickle.load(f)
# pu.plot_history(history2, f"{cfg.save_model_dir}/{model_names[7]}_history.png")

# %%
# Convert the model to a quantization aware model
quant_aware_model = get_model(
    cfg.img_size, cfg.num_classes, in_channels=cfg.in_channels, use_qat=True
)
model_name = model_names[2]
fit_eval(quant_aware_model, model_name)
quant_aware_model_converted = converter.eight_bit_quantization(
    quant_aware_model, ds_train, model_name=model_name
)
write_model_h(cfiles[model_name], quant_aware_model_converted, cfg.save_cfiles_dir)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 27s 1s/step - loss: 0.1183 - custom_metric: 0.7386 - val_loss: 0.2184 - val_custom_metric: 0.5373 - lr: 5.0000e-04
# Epoch 2/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0695 - custom_metric: 0.7217 - val_loss: 0.1265 - val_custom_metric: 0.4129 - lr: 5.0000e-04
# Epoch 3/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0662 - custom_metric: 0.6448 - val_loss: 0.0984 - val_custom_metric: 0.3532 - lr: 5.0000e-04
# Epoch 4/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0600 - custom_metric: 0.5376 - val_loss: 0.0940 - val_custom_metric: 0.3319 - lr: 5.0000e-04
# Epoch 5/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0521 - custom_metric: 0.4226 - val_loss: 0.0685 - val_custom_metric: 0.2537 - lr: 5.0000e-04
# Epoch 6/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0439 - custom_metric: 0.3168 - val_loss: 0.0579 - val_custom_metric: 0.2198 - lr: 5.0000e-04
# Epoch 7/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0379 - custom_metric: 0.2449 - val_loss: 0.0506 - val_custom_metric: 0.1952 - lr: 5.0000e-04
# Epoch 8/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0332 - custom_metric: 0.1969 - val_loss: 0.0469 - val_custom_metric: 0.1833 - lr: 5.0000e-04
# Epoch 9/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0301 - custom_metric: 0.1671 - val_loss: 0.0373 - val_custom_metric: 0.1478 - lr: 5.0000e-04
# Epoch 10/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0288 - custom_metric: 0.1533 - val_loss: 0.0309 - val_custom_metric: 0.1268 - lr: 5.0000e-04
# Epoch 11/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0277 - custom_metric: 0.1431 - val_loss: 0.0299 - val_custom_metric: 0.1278 - lr: 5.0000e-04
# Epoch 12/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0270 - custom_metric: 0.1358 - val_loss: 0.0304 - val_custom_metric: 0.1316 - lr: 5.0000e-04
# Epoch 13/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0261 - custom_metric: 0.1290 - val_loss: 0.0309 - val_custom_metric: 0.1370 - lr: 5.0000e-04
# Epoch 14/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0257 - custom_metric: 0.1246 - val_loss: 0.0326 - val_custom_metric: 0.1523 - lr: 5.0000e-04
# Epoch 15/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.0253 - custom_metric: 0.1211 - val_loss: 0.0333 - val_custom_metric: 0.1567 - lr: 5.0000e-04
# Epoch 16/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0250 - custom_metric: 0.1179
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 24/24 [==============================] - 24s 1s/step - loss: 0.0250 - custom_metric: 0.1179 - val_loss: 0.0344 - val_custom_metric: 0.1658 - lr: 5.0000e-04
# Epoch 17/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0243 - custom_metric: 0.1140 - val_loss: 0.0333 - val_custom_metric: 0.1538 - lr: 1.0000e-04
# Epoch 18/50
# 24/24 [==============================] - 23s 997ms/step - loss: 0.0243 - custom_metric: 0.1138 - val_loss: 0.0331 - val_custom_metric: 0.1523 - lr: 1.0000e-04
# Epoch 19/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0242 - custom_metric: 0.1134 - val_loss: 0.0325 - val_custom_metric: 0.1479 - lr: 1.0000e-04
# Epoch 20/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0242 - custom_metric: 0.1131 - val_loss: 0.0310 - val_custom_metric: 0.1365 - lr: 1.0000e-04
# Epoch 21/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0240 - custom_metric: 0.1123
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 24/24 [==============================] - 24s 1s/step - loss: 0.0240 - custom_metric: 0.1123 - val_loss: 0.0294 - val_custom_metric: 0.1263 - lr: 1.0000e-04
# Epoch 22/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0240 - custom_metric: 0.1116 - val_loss: 0.0280 - val_custom_metric: 0.1182 - lr: 2.0000e-05
# WARNING:absl:Found untraced functions such as conv2d_layer_call_fn, conv2d_layer_call_and_return_conditional_losses, _jit_compiled_convolution_op, activation_layer_call_fn, activation_layer_call_and_return_conditional_losses while saving (showing 5 of 83). These functions will not be directly callable after loading.
# Model was saved at location: /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/depth_qat_int8.tflite
# HDF5 Model size: 1294 KB
# TFLite Model size: 643 KB
#
# Reduction in file size by a factor of 2.012106
# Evaluated on 100 images.
# Evaluated on 200 images.
# Evaluated on 300 images.
# Evaluated on 400 images.
# Evaluated on 500 images.
# Evaluated on 600 images.
# Evaluated on 700 images.
# Evaluated on 800 images.
# Evaluated on 900 images.
# Evaluated on 1000 images.
# Evaluated on 1100 images.
# Evaluated on 1200 images.
# Evaluated on 1300 images.
# Evaluated on 1400 images.
# Evaluated on 1500 images.
# Evaluated on 1600 images.
# Evaluated on 1700 images.
# Evaluated on 1800 images.
# Evaluated on 1900 images.
# Evaluated on 2000 images.
# Evaluated on 2100 images.
# Evaluated on 2200 images.
# Evaluated on 2300 images.
# Evaluated on 2400 images.
# Evaluated on 2500 images.
# Evaluated on 2600 images.
# Evaluated on 2700 images.
# Evaluated on 2800 images.
# Evaluated on 2900 images.
# depth_qat_int8 model metrics:
# mse: 0.002
# mae: 0.033
# eval_loss: 0.033
# eval_metric: 0.154
# Saved metrics to /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/metrics.json
# WARNING:absl:Found untraced functions such as conv2d_layer_call_fn, conv2d_layer_call_and_return_conditional_losses, _jit_compiled_convolution_op, activation_layer_call_fn, activation_layer_call_and_return_conditional_losses while saving (showing 5 of 83). These functions will not be directly callable after loading.
# /home/master/.conda/envs/sc/lib/python3.9/site-packages/tensorflow/lite/python/convert.py:765: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# Model was saved at location: /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/depth_qat_int8.tflite
# TFLite Model size with 8-bit quantization: 108 KB
# TFLite Model size without quantization: 300 KB
#
# Reduction in model size by a factor of 2.772839
# fully_quantize: 0, inference_type: 6, input_inference_type: UINT8, output_inference_type: UINT8

# %%
model_name = model_names[3]
pruned_model = get_model(cfg.img_size, cfg.num_classes, in_channels=cfg.in_channels, use_qat=False, use_pruning=True,
                         use_pruning_struct=True)
fit_eval(pruned_model, model_name, do_save_model=False)
pruned_model_for_export = save_pruned_model(pruned_model, f"{cfg.save_model_dir}/{model_name}.h5")
pruned_tflite_model = converter.keras_to_tflite(pruned_model_for_export, model_name)
write_model_h(cfiles[model_name], pruned_tflite_model, cfg.save_cfiles_dir)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 29s 1s/step - loss: 0.3022 - custom_metric: 0.7828 - val_loss: 0.2217 - val_custom_metric: 0.5167 - lr: 5.0000e-04
# Epoch 2/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0833 - custom_metric: 0.5564 - val_loss: 0.1402 - val_custom_metric: 0.4291 - lr: 5.0000e-04
# Epoch 3/50
# 24/24 [==============================] - 23s 995ms/step - loss: 0.0586 - custom_metric: 0.5025 - val_loss: 0.0865 - val_custom_metric: 0.3261 - lr: 5.0000e-04
# Epoch 4/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0535 - custom_metric: 0.4286 - val_loss: 0.0665 - val_custom_metric: 0.2795 - lr: 5.0000e-04
# Epoch 5/50
# 24/24 [==============================] - 24s 999ms/step - loss: 0.0480 - custom_metric: 0.3595 - val_loss: 0.0551 - val_custom_metric: 0.2420 - lr: 5.0000e-04
# Epoch 6/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0422 - custom_metric: 0.2960 - val_loss: 0.0462 - val_custom_metric: 0.2051 - lr: 5.0000e-04
# Epoch 7/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0366 - custom_metric: 0.2382 - val_loss: 0.0439 - val_custom_metric: 0.1947 - lr: 5.0000e-04
# Epoch 8/50
# 24/24 [==============================] - 23s 999ms/step - loss: 0.0330 - custom_metric: 0.1998 - val_loss: 0.0367 - val_custom_metric: 0.1620 - lr: 5.0000e-04
# Epoch 9/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0308 - custom_metric: 0.1760 - val_loss: 0.0340 - val_custom_metric: 0.1496 - lr: 5.0000e-04
# Epoch 10/50
# 24/24 [==============================] - 23s 995ms/step - loss: 0.0294 - custom_metric: 0.1612 - val_loss: 0.0321 - val_custom_metric: 0.1406 - lr: 5.0000e-04
# Epoch 11/50
# 24/24 [==============================] - 23s 980ms/step - loss: 0.0284 - custom_metric: 0.1505 - val_loss: 0.0306 - val_custom_metric: 0.1332 - lr: 5.0000e-04
# Epoch 12/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0276 - custom_metric: 0.1424
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 24/24 [==============================] - 23s 991ms/step - loss: 0.0276 - custom_metric: 0.1424 - val_loss: 0.0296 - val_custom_metric: 0.1277 - lr: 5.0000e-04
# Epoch 13/50
# 24/24 [==============================] - 23s 983ms/step - loss: 0.0270 - custom_metric: 0.1372 - val_loss: 0.0290 - val_custom_metric: 0.1249 - lr: 1.0000e-04
# Epoch 14/50
# 24/24 [==============================] - 23s 991ms/step - loss: 0.0268 - custom_metric: 0.1356 - val_loss: 0.0289 - val_custom_metric: 0.1253 - lr: 1.0000e-04
# Epoch 15/50
# 24/24 [==============================] - 23s 984ms/step - loss: 0.0267 - custom_metric: 0.1345 - val_loss: 0.0290 - val_custom_metric: 0.1264 - lr: 1.0000e-04
# Epoch 16/50
# 24/24 [==============================] - 23s 989ms/step - loss: 0.0266 - custom_metric: 0.1333 - val_loss: 0.0291 - val_custom_metric: 0.1272 - lr: 1.0000e-04
# Epoch 17/50
# 24/24 [==============================] - 23s 985ms/step - loss: 0.0265 - custom_metric: 0.1322 - val_loss: 0.0291 - val_custom_metric: 0.1272 - lr: 1.0000e-04
# Epoch 18/50
# 24/24 [==============================] - 23s 990ms/step - loss: 0.0264 - custom_metric: 0.1311 - val_loss: 0.0289 - val_custom_metric: 0.1263 - lr: 1.0000e-04
# Epoch 19/50
# 24/24 [==============================] - 23s 985ms/step - loss: 0.0263 - custom_metric: 0.1300 - val_loss: 0.0286 - val_custom_metric: 0.1247 - lr: 1.0000e-04
# Epoch 20/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0262 - custom_metric: 0.1290 - val_loss: 0.0283 - val_custom_metric: 0.1226 - lr: 1.0000e-04
# Epoch 21/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0261 - custom_metric: 0.1280
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 24/24 [==============================] - 25s 1s/step - loss: 0.0261 - custom_metric: 0.1280 - val_loss: 0.0278 - val_custom_metric: 0.1203 - lr: 1.0000e-04
# Epoch 22/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0260 - custom_metric: 0.1269 - val_loss: 0.0274 - val_custom_metric: 0.1188 - lr: 2.0000e-05
# Epoch 23/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0259 - custom_metric: 0.1267 - val_loss: 0.0270 - val_custom_metric: 0.1178 - lr: 2.0000e-05
# pruned_model model metrics:
# eval_loss: 0.029
# eval_metric: 0.126
# Saved metrics to /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/metrics.json
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved pruned Keras model to: /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/pruned_model.h5
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 17). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmp4ypcaf8j/assets
# INFO:tensorflow:Assets written to: /tmp/tmp4ypcaf8j/assets
# Model was saved at location: /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/pruned_model.tflite
# HDF5 Model size: 431 KB
# TFLite Model size: 300 KB
#
# Reduction in file size by a factor of 1.434413

# %%
model_name = model_names[4]
pruned_model_unstruct = get_model(
    cfg.img_size,
    cfg.num_classes,
    in_channels=cfg.in_channels,
    use_qat=False,
    use_pruning=True,
    use_pruning_struct=False,
    use_dynamic_sparsity=False,
)
fit_eval(pruned_model_unstruct, model_name, do_save_model=False)
pruned_model_for_export = save_pruned_model(
    pruned_model_unstruct, f"{cfg.save_model_dir}/{model_name}.h5"
)
pruned_tflite_model = converter.keras_to_tflite(pruned_model_for_export, model_name)
eval_model(
        model=pruned_model_unstruct,
        test_ds=ds_val,
        tflite_path=f"{cfg.save_model_dir}/{model_name}.tflite",
        model_name=model_name,
        metrics_file_path=f"{cfg.save_model_dir}/metrics.json",
    )
write_model_h(cfiles[model_name], pruned_tflite_model, cfg.save_cfiles_dir)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 30s 1s/step - loss: 0.2378 - custom_metric: 0.8367 - val_loss: 0.2626 - val_custom_metric: 0.5465 - lr: 5.0000e-04
# Epoch 2/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0707 - custom_metric: 0.5729 - val_loss: 0.1573 - val_custom_metric: 0.4242 - lr: 5.0000e-04
# Epoch 3/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0583 - custom_metric: 0.5566 - val_loss: 0.1181 - val_custom_metric: 0.3572 - lr: 5.0000e-04
# Epoch 4/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0527 - custom_metric: 0.4778 - val_loss: 0.0871 - val_custom_metric: 0.2915 - lr: 5.0000e-04
# Epoch 5/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0467 - custom_metric: 0.3915 - val_loss: 0.0795 - val_custom_metric: 0.2755 - lr: 5.0000e-04
# Epoch 6/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0410 - custom_metric: 0.3069 - val_loss: 0.0787 - val_custom_metric: 0.2757 - lr: 5.0000e-04
# Epoch 7/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0366 - custom_metric: 0.2490 - val_loss: 0.0613 - val_custom_metric: 0.2275 - lr: 5.0000e-04
# Epoch 8/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0336 - custom_metric: 0.2135 - val_loss: 0.0488 - val_custom_metric: 0.1895 - lr: 5.0000e-04
# Epoch 9/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0316 - custom_metric: 0.1898 - val_loss: 0.0421 - val_custom_metric: 0.1688 - lr: 5.0000e-04
# Epoch 10/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0301 - custom_metric: 0.1734 - val_loss: 0.0382 - val_custom_metric: 0.1573 - lr: 5.0000e-04
# Epoch 11/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0290 - custom_metric: 0.1611 - val_loss: 0.0356 - val_custom_metric: 0.1503 - lr: 5.0000e-04
# Epoch 12/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0282 - custom_metric: 0.1517
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 24/24 [==============================] - 24s 1s/step - loss: 0.0282 - custom_metric: 0.1517 - val_loss: 0.0339 - val_custom_metric: 0.1463 - lr: 5.0000e-04
# Epoch 13/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.0276 - custom_metric: 0.1457 - val_loss: 0.0328 - val_custom_metric: 0.1450 - lr: 1.0000e-04
# Epoch 14/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0274 - custom_metric: 0.1445 - val_loss: 0.0322 - val_custom_metric: 0.1453 - lr: 1.0000e-04
# Epoch 15/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0273 - custom_metric: 0.1430 - val_loss: 0.0317 - val_custom_metric: 0.1444 - lr: 1.0000e-04
# Epoch 16/50
# 24/24 [==============================] - 27s 1s/step - loss: 0.0272 - custom_metric: 0.1417 - val_loss: 0.0313 - val_custom_metric: 0.1433 - lr: 1.0000e-04
# Epoch 17/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0270 - custom_metric: 0.1404
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 24/24 [==============================] - 27s 1s/step - loss: 0.0270 - custom_metric: 0.1404 - val_loss: 0.0309 - val_custom_metric: 0.1415 - lr: 1.0000e-04
# Epoch 18/50
# 24/24 [==============================] - 27s 1s/step - loss: 0.0269 - custom_metric: 0.1395 - val_loss: 0.0305 - val_custom_metric: 0.1395 - lr: 2.0000e-05
# Epoch 19/50
# 24/24 [==============================] - 26s 1s/step - loss: 0.0269 - custom_metric: 0.1390 - val_loss: 0.0302 - val_custom_metric: 0.1368 - lr: 2.0000e-05
# Epoch 20/50
# 24/24 [==============================] - 27s 1s/step - loss: 0.0269 - custom_metric: 0.1388 - val_loss: 0.0299 - val_custom_metric: 0.1339 - lr: 2.0000e-05
# Epoch 21/50
# 24/24 [==============================] - 27s 1s/step - loss: 0.0268 - custom_metric: 0.1385 - val_loss: 0.0295 - val_custom_metric: 0.1308 - lr: 2.0000e-05
# Epoch 22/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0268 - custom_metric: 0.1382
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.000000262749381e-06.
# 24/24 [==============================] - 25s 1s/step - loss: 0.0268 - custom_metric: 0.1382 - val_loss: 0.0290 - val_custom_metric: 0.1276 - lr: 2.0000e-05
# pruned_model_unstructured model metrics:
# eval_loss: 0.031
# eval_metric: 0.141
# Saved metrics to /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/metrics.json
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved pruned Keras model to: /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/pruned_model_unstructured.h5
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 17). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmp_1wdyrq6/assets
# INFO:tensorflow:Assets written to: /tmp/tmp_1wdyrq6/assets
# Model was saved at location: /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/pruned_model_unstructured.tflite
# HDF5 Model size: 431 KB
# TFLite Model size: 300 KB
#
# Reduction in file size by a factor of 1.434413
# Evaluated on 100 images.
# Evaluated on 200 images.
# Evaluated on 300 images.
# Evaluated on 400 images.
# Evaluated on 500 images.
# Evaluated on 600 images.
# Evaluated on 700 images.
# Evaluated on 800 images.
# Evaluated on 900 images.
# Evaluated on 1000 images.
# Evaluated on 1100 images.
# Evaluated on 1200 images.
# Evaluated on 1300 images.
# Evaluated on 1400 images.
# Evaluated on 1500 images.
# Evaluated on 1600 images.
# Evaluated on 1700 images.
# Evaluated on 1800 images.
# Evaluated on 1900 images.
# Evaluated on 2000 images.
# Evaluated on 2100 images.
# Evaluated on 2200 images.
# Evaluated on 2300 images.
# Evaluated on 2400 images.
# Evaluated on 2500 images.
# Evaluated on 2600 images.
# Evaluated on 2700 images.
# Evaluated on 2800 images.
# Evaluated on 2900 images.
# pruned_model_unstructured model metrics:
# mse: 0.002
# mae: 0.031
# eval_loss: 0.031
# eval_metric: 0.141
# Saved metrics to /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/metrics.json

# %%
model_name = model_names[5]
pruned_model_unstruct_dynamic = get_model(
    cfg.img_size,
    cfg.num_classes,
    in_channels=cfg.in_channels,
    use_qat=False,
    use_pruning=True,
    use_pruning_struct=False,
    use_dynamic_sparsity=True,
)
fit_eval(pruned_model_unstruct_dynamic, model_name, do_save_model=False)
pruned_model_unstructured_for_export = save_pruned_model(
    pruned_model_unstruct_dynamic, f"{cfg.save_model_dir}/{model_name}.h5"
)
pruned_tflite_model = converter.keras_to_tflite(pruned_model_unstructured_for_export, model_name)
eval_model(
        model=pruned_model_unstruct_dynamic,
        test_ds=ds_val,
        tflite_path=f"{cfg.save_model_dir}/{model_name}.tflite",
        model_name=model_name,
        metrics_file_path=f"{cfg.save_model_dir}/metrics.json",
    )
write_model_h(cfiles[model_name], pruned_tflite_model, cfg.save_cfiles_dir)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 32s 1s/step - loss: 0.1418 - custom_metric: 0.7135 - val_loss: 0.3316 - val_custom_metric: 0.6153 - lr: 5.0000e-04
# Epoch 2/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0689 - custom_metric: 0.7234 - val_loss: 0.3007 - val_custom_metric: 0.5999 - lr: 5.0000e-04
# Epoch 3/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0615 - custom_metric: 0.5770 - val_loss: 0.2203 - val_custom_metric: 0.5232 - lr: 5.0000e-04
# Epoch 4/50
# 24/24 [==============================] - 23s 995ms/step - loss: 0.0564 - custom_metric: 0.4105 - val_loss: 0.1847 - val_custom_metric: 0.4708 - lr: 5.0000e-04
# Epoch 5/50
# 24/24 [==============================] - 23s 990ms/step - loss: 0.0586 - custom_metric: 0.4979 - val_loss: 0.1376 - val_custom_metric: 0.3878 - lr: 5.0000e-04
# Epoch 6/50
# 24/24 [==============================] - 23s 982ms/step - loss: 0.0661 - custom_metric: 0.4295 - val_loss: 0.0685 - val_custom_metric: 0.2332 - lr: 5.0000e-04
# Epoch 7/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.0583 - custom_metric: 0.5237 - val_loss: 0.1004 - val_custom_metric: 0.3304 - lr: 5.0000e-04
# Epoch 8/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0535 - custom_metric: 0.3268 - val_loss: 0.0791 - val_custom_metric: 0.2735 - lr: 5.0000e-04
# Epoch 9/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0491 - custom_metric: 0.3825
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 24/24 [==============================] - 24s 1s/step - loss: 0.0491 - custom_metric: 0.3825 - val_loss: 0.0778 - val_custom_metric: 0.2579 - lr: 5.0000e-04
# Epoch 10/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.0402 - custom_metric: 0.2594 - val_loss: 0.0513 - val_custom_metric: 0.1786 - lr: 1.0000e-04
# Epoch 11/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.0360 - custom_metric: 0.2052 - val_loss: 0.0441 - val_custom_metric: 0.1570 - lr: 1.0000e-04
# Epoch 12/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0311 - custom_metric: 0.1694 - val_loss: 0.0504 - val_custom_metric: 0.1839 - lr: 1.0000e-04
# Epoch 13/50
# 24/24 [==============================] - 23s 995ms/step - loss: 0.0465 - custom_metric: 0.2076 - val_loss: 0.0613 - val_custom_metric: 0.2108 - lr: 1.0000e-04
# Epoch 14/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0971 - custom_metric: 0.3634 - val_loss: 0.0684 - val_custom_metric: 0.2341 - lr: 1.0000e-04
# Epoch 15/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0390 - custom_metric: 0.1846
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 24/24 [==============================] - 24s 1s/step - loss: 0.0390 - custom_metric: 0.1846 - val_loss: 0.0485 - val_custom_metric: 0.1741 - lr: 1.0000e-04
# Epoch 16/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.0304 - custom_metric: 0.1458 - val_loss: 0.0412 - val_custom_metric: 0.1502 - lr: 2.0000e-05
# Epoch 17/50
# 24/24 [==============================] - 23s 992ms/step - loss: 0.0297 - custom_metric: 0.1420 - val_loss: 0.0386 - val_custom_metric: 0.1426 - lr: 2.0000e-05
# Epoch 18/50
# 24/24 [==============================] - 23s 1000ms/step - loss: 0.0294 - custom_metric: 0.1406 - val_loss: 0.0363 - val_custom_metric: 0.1358 - lr: 2.0000e-05
# Epoch 19/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0291 - custom_metric: 0.1395 - val_loss: 0.0344 - val_custom_metric: 0.1302 - lr: 2.0000e-05
# Epoch 20/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0290 - custom_metric: 0.1385 - val_loss: 0.0328 - val_custom_metric: 0.1258 - lr: 2.0000e-05
# Epoch 21/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0288 - custom_metric: 0.1377 - val_loss: 0.0316 - val_custom_metric: 0.1226 - lr: 2.0000e-05
# Epoch 22/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0287 - custom_metric: 0.1370
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.000000262749381e-06.
# 24/24 [==============================] - 24s 1s/step - loss: 0.0287 - custom_metric: 0.1370 - val_loss: 0.0307 - val_custom_metric: 0.1203 - lr: 2.0000e-05
# Epoch 23/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0286 - custom_metric: 0.1366 - val_loss: 0.0300 - val_custom_metric: 0.1190 - lr: 4.0000e-06
# pruned_model_unstructured_dynamic model metrics:
# eval_loss: 0.036
# eval_metric: 0.136
# Saved metrics to /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/metrics.json
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved pruned Keras model to: /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/pruned_model_unstructured_dynamic.h5
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 17). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmpljvi5kfr/assets
# INFO:tensorflow:Assets written to: /tmp/tmpljvi5kfr/assets
# Model was saved at location: /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/pruned_model_unstructured_dynamic.tflite
# HDF5 Model size: 431 KB
# TFLite Model size: 300 KB
#
# Reduction in file size by a factor of 1.434413
# Evaluated on 100 images.
# Evaluated on 200 images.
# Evaluated on 300 images.
# Evaluated on 400 images.
# Evaluated on 500 images.
# Evaluated on 600 images.
# Evaluated on 700 images.
# Evaluated on 800 images.
# Evaluated on 900 images.
# Evaluated on 1000 images.
# Evaluated on 1100 images.
# Evaluated on 1200 images.
# Evaluated on 1300 images.
# Evaluated on 1400 images.
# Evaluated on 1500 images.
# Evaluated on 1600 images.
# Evaluated on 1700 images.
# Evaluated on 1800 images.
# Evaluated on 1900 images.
# Evaluated on 2000 images.
# Evaluated on 2100 images.
# Evaluated on 2200 images.
# Evaluated on 2300 images.
# Evaluated on 2400 images.
# Evaluated on 2500 images.
# Evaluated on 2600 images.
# Evaluated on 2700 images.
# Evaluated on 2800 images.
# Evaluated on 2900 images.
# pruned_model_unstructured_dynamic model metrics:
# mse: 0.002
# mae: 0.036
# eval_loss: 0.036
# eval_metric: 0.136
# Saved metrics to /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/metrics.json

# %%
model_name = model_names[6]
pruned_qat_model = get_model(
    cfg.img_size,
    cfg.num_classes,
    in_channels=cfg.in_channels,
    use_qat=True,
    use_pruning=True,
    use_pruning_struct=False,
    use_dynamic_sparsity=False,
    pruned_model_unstructured_for_export=pruned_model_unstructured_for_export
)
fit_eval(pruned_qat_model, model_name, do_save_model=False)
pruned_model_for_export = save_pruned_model(
    pruned_qat_model, f"{cfg.save_model_dir}/{model_name}.h5"
)
pruned_tflite_model = converter.keras_to_tflite(pruned_model_for_export, model_name)
eval_model(
        model=pruned_qat_model,
        test_ds=ds_val,
        tflite_path=f"{cfg.save_model_dir}/{model_name}.tflite",
        model_name=model_name,
        metrics_file_path=f"{cfg.save_model_dir}/metrics.json",
    )
write_model_h(cfiles[model_name], pruned_tflite_model, cfg.save_cfiles_dir)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 27s 1s/step - loss: 0.0272 - custom_metric: 0.1227 - val_loss: 0.0337 - val_custom_metric: 0.1299 - lr: 5.0000e-04
# Epoch 2/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0251 - custom_metric: 0.1056 - val_loss: 0.0325 - val_custom_metric: 0.1271 - lr: 5.0000e-04
# Epoch 3/50
# 24/24 [==============================] - 24s 1s/step - loss: 0.0245 - custom_metric: 0.1004 - val_loss: 0.0298 - val_custom_metric: 0.1175 - lr: 5.0000e-04
# Epoch 4/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.0240 - custom_metric: 0.0975 - val_loss: 0.0286 - val_custom_metric: 0.1155 - lr: 5.0000e-04
# Epoch 5/50
# 24/24 [==============================] - 26s 1s/step - loss: 0.0237 - custom_metric: 0.0955 - val_loss: 0.0289 - val_custom_metric: 0.1196 - lr: 5.0000e-04
# Epoch 6/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0234 - custom_metric: 0.0939
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 24/24 [==============================] - 25s 1s/step - loss: 0.0234 - custom_metric: 0.0939 - val_loss: 0.0291 - val_custom_metric: 0.1226 - lr: 5.0000e-04
# Epoch 7/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.0229 - custom_metric: 0.0911 - val_loss: 0.0288 - val_custom_metric: 0.1199 - lr: 1.0000e-04
# Epoch 8/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.0228 - custom_metric: 0.0907 - val_loss: 0.0285 - val_custom_metric: 0.1185 - lr: 1.0000e-04
# Epoch 9/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.0228 - custom_metric: 0.0906 - val_loss: 0.0277 - val_custom_metric: 0.1132 - lr: 1.0000e-04
# Epoch 10/50
# 24/24 [==============================] - 25s 1s/step - loss: 0.0227 - custom_metric: 0.0902 - val_loss: 0.0270 - val_custom_metric: 0.1088 - lr: 1.0000e-04
# Epoch 11/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0226 - custom_metric: 0.0897
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 24/24 [==============================] - 25s 1s/step - loss: 0.0226 - custom_metric: 0.0897 - val_loss: 0.0266 - val_custom_metric: 0.1068 - lr: 1.0000e-04
# pruned_qat_model model metrics:
# eval_loss: 0.029
# eval_metric: 0.123
# Saved metrics to /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/metrics.json
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved pruned Keras model to: /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/pruned_qat_model.h5
# WARNING:absl:Found untraced functions such as conv2d_layer_call_fn, conv2d_layer_call_and_return_conditional_losses, _jit_compiled_convolution_op, activation_layer_call_fn, activation_layer_call_and_return_conditional_losses while saving (showing 5 of 83). These functions will not be directly callable after loading.
# Model was saved at location: /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/pruned_qat_model.tflite
# HDF5 Model size: 587 KB
# TFLite Model size: 643 KB
#
# Reduction in file size by a factor of 0.913258
# Evaluated on 100 images.
# Evaluated on 200 images.
# Evaluated on 300 images.
# Evaluated on 400 images.
# Evaluated on 500 images.
# Evaluated on 600 images.
# Evaluated on 700 images.
# Evaluated on 800 images.
# Evaluated on 900 images.
# Evaluated on 1000 images.
# Evaluated on 1100 images.
# Evaluated on 1200 images.
# Evaluated on 1300 images.
# Evaluated on 1400 images.
# Evaluated on 1500 images.
# Evaluated on 1600 images.
# Evaluated on 1700 images.
# Evaluated on 1800 images.
# Evaluated on 1900 images.
# Evaluated on 2000 images.
# Evaluated on 2100 images.
# Evaluated on 2200 images.
# Evaluated on 2300 images.
# Evaluated on 2400 images.
# Evaluated on 2500 images.
# Evaluated on 2600 images.
# Evaluated on 2700 images.
# Evaluated on 2800 images.
# Evaluated on 2900 images.
# pruned_qat_model model metrics:
# mse: 0.002
# mae: 0.029
# eval_loss: 0.029
# eval_metric: 0.123
# Saved metrics to /media/master/wext/msc_studies/second_semester/microcontrollers/project/stm32/code/models/metrics.json
